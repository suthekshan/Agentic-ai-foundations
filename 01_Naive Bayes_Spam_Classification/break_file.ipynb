# %% [markdown]
# Task 1. Import the correct libraries

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import _____  # Hint: Vectorizer
from sklearn.naive_bayes import ______           # Hint: Model
from sklearn.metrics import accuracy_score, classification_report

# %% [markdown]
# Task 2: load your Data

# %% [markdown]
# Download the dataset from the provided link: https://www.kaggle.com/datasets/uciml/sms-spam-collection-dataset

# %%
df = pd.read_csv("", encoding='latin-1')
df = df[['v1', 'v2']]
df.columns = ['label', 'text']

# %%
# TODO: Fill in the missing arguments
vectorizer = TfidfVectorizer(
    _______ = 'english', # Keyword to remove common words
    _______ = True        # Keyword to ensure case-insensitivity
)

X = vectorizer.fit_transform(df['text'])
y = df['label']

# %% [markdown]
# Task 3: Correct the train test split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size = 0.99, random_state = 42
)

# %% [markdown]
# Task 4: Initialize the model for the data

# %%
model = _______() 
model._______(X_train, y_train)

# %% [markdown]
# Task 5: Find the suitable alpha value(It represents Laplace smoothing alpha=0.0 no smoothing, alpha=1.0 add one smoothing)

# %%
alpha_value = _______ 

tuned_model = _________(alpha=alpha_value)
tuned_model._______(X_train, y_train)
predictions = tuned_model.predict(X_test)

from sklearn.metrics import accuracy_score, classification_report
print(f"Accuracy with alpha {alpha_value}: {accuracy_score(y_test, predictions)}")
print(classification_report(y_test, predictions))

# %% [markdown]
# Task 6: Find the impact score

# %%
feature_names = vectorizer.get_feature_names_out()
spam_log_prob = model.feature_log_prob_[1]
ham_log_prob = model.feature_log_prob_[0]

impact_score = _______ - _______

impact_df = pd.DataFrame({'word': feature_names, 'score': impact_score})
print("Top 5 Spam Words:")
print(impact_df.sort_values(by='score', ascending=False).head(5))

# %% [markdown]
# Task 7: test it with your own email

# %%
my_email = ["_______"]

my_email_transformed = vectorizer.transform(my_email)

prediction = model.predict(my_email_transformed)
result = "SPAM" if prediction[0] == 1 else "HAM"

print(f"The model classified your email as: {result}")
